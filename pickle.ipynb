# %%
import pandas as pd

# %% [markdown]
# @author: MUSTAFA YALINIZ

# %%
# Dosya oku 
data = pd.read_csv('satislar.csv')
data.head()
# Out:
#    Aylar  Satislar
# 0      8   19671.5
# 1     10   23102.5
# 2     11   18865.5
# 3     13   21762.5
# 4     14   19945.5

# %%
# Bagimli ve bagimsiz degisken olarak ayir
X = data.iloc[:,0:1].values
Y = data.iloc[:,1].values

# %%
# Test ve train olarak ayir
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
# Veriyi gorsellestir
from matplotlib import pyplot as plt
plt.scatter(X_test,Y_test,label='Test Data')
plt.xlabel('Aylar')
plt.ylabel('Satislar')
plt.title('Test Data')
plt.legend()
plt.show()

# %%
# Veriyi egit
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# Veriyi kaydet 
import pickle
pickle.dump(lr, open('model.pkl', 'wb'))

# %%
# Veriyi oku 
model=pickle.load(open('model.pkl', 'rb'))
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([19964.71367343, 58910.47566014, 30987.09914137, 30252.27344351,
#        55236.34717083, 51562.21868152])

# %%
# Tahmini gorsellestir
plt.scatter(X_test,Y_test,label='Test Data')
plt.plot(X_test,Y_pred,label='Predicted Data',color='red')
plt.title('Test Data')
plt.xlabel('Aylar')
plt.ylabel('Satislar')
plt.legend()
plt.show()
