# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# @author: MUSTAFA YALINIZ

# %%
# Veriyi oku
data=pd.read_csv('maaslar.csv')

# %%
# Veriyi bol
X=data.iloc[:,1:2].values
Y=data.iloc[:,2:].values

# %%
# Veriyi egit
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor(random_state=0)
dtr.fit(X,Y)

# %%
# Grafigi olustur
plt.scatter(X,Y,color='red')
plt.plot(X,dtr.predict(X))
plt.title("Decision Tree Regression")
plt.xlabel("Bagimsiz Degisken")
plt.ylabel("Bagimli Degisken")
plt.legend(["Veri","Tahmin"])
plt.show()

# %%
# '6.6' deger icin tahmin
veri = dtr.predict([[6.6]])
veri
# Out:
# array([10000.])

# %%
# Butun X lere gore siniflara ayirdi X = 10 dan sonrasina hep 50.000 
veri1 = dtr.predict([[100]])
veri1
# Out:
# array([50000.])
