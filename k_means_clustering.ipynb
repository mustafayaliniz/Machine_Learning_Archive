# %%
import pandas as pd
import numpy as np

# %% [markdown]
# @author: MUSTAFA YALINIZ

# %%
# Veriyi oku 
data = pd.read_csv('musteriler.csv')
data
# Out:
#       No Cinsiyet  Yas  Hacim  Maas
# 0      1        K   60  69900  6325
# 1      2        K   30  79000  5200
# 2      3        E   52  85500  7825
# 3      4        E   57  17100  8375
# 4      5        E   55   5500  5450
# ..   ...      ...  ...    ...   ...
# 195  196        E   22  96600  7900
# 196  197        E   39  83700  7675
# 197  198        K   25  34000  4000
# 198  199        K   30  42000  5500
# 199  200        K   23  47600  4150
#
# [200 rows x 5 columns]

# %%
# Veriyi bol
X = data.iloc[:, 3:].values

# %% [markdown]
# [Documentation KMeans](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)

# %%
# Veriyi egit
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=0, init='k-means++') # init= random da olabilir ama en iyi secenek k-means++
kmeans.fit(X)
pred=kmeans.predict(X)

# %%
# Gorsel olustur
from matplotlib import pyplot as plt
sonuclar = []
for i in range(1,11):
    model = KMeans(n_clusters=i, random_state=0, init='k-means++')
    model.fit(X)
    sonuclar.append(model.inertia_)
plt.plot(range(1,11), sonuclar, label='WCSS',linewidth=3)
plt.xlabel('Number of clusters', fontsize=14)
plt.ylabel('Inertia', fontsize=14)
plt.title('K-Means Clustering', fontweight='bold')
plt.legend()
plt.show()

# %%
plt.scatter(X[pred==0,0], X[pred==0,1], s=100, c='red',label='Sinif1')
plt.scatter(X[pred==1,0], X[pred==1,1], s=100, c='green',label='Sinif2')
plt.scatter(X[pred==2,0], X[pred==2,1], s=100, c='yellow',label='Sinif3')
plt.title('K-Means Clustering', fontweight='bold')
plt.legend()
plt.show()
